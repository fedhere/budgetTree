# %%
import pandas as pd

# %%
Ob2011 = pd.read_csv("wikiObama2011.csv", header=None, names=["Item","Discretionary, requested","Discretionary, enacted","Mandatory, requested","Mandatory, enacted"])

# %%
Ob2011
# Out:
#                                                  Item  \
# 0                        SocialSecurityAdministration
# 1   DepartmentofHealthandHumanServicesincludingMed...
# 2   DepartmentofDefenseincludingOverseasContingenc...
# 3                               DepartmentofEducation
# 4                             DepartmentofAgriculture
# 5                         DepartmentofVeteransAffairs
# 6              DepartmentofHousingandUrbanDevelopment
# 7      DepartmentofStateandOtherInternationalPrograms
# 8                        DepartmentofHomelandSecurity
# 9                                  DepartmentofEnergy
# 10                                DepartmentofJustice
# 11          NationalAeronauticsandSpaceAdministration
# 12                         DepartmentofTransportation
# 13                            DepartmentoftheTreasury
# 14                            DepartmentoftheInterior
# 15                                  DepartmentofLabor
# ...

# %%
Ob2011[1]
# Out:
# 0      12.500
# 1      88.600
# 2     701.600
# 3      78.900
# 4      27.600
# 5      58.800
# 6      49.800
# 7      62.700
# 8      46.300
# 9      42.500
# 10     24.100
# 11     18.200
# 12     27.000
# 13     14.600
# 14     13.100
# 15     13.700
# 16     11.300
# 17      7.900
# 18     10.200
# 19      7.600
# 20      1.200
# 21      1.100
# 22        NaN
# 23      0.006
# 24     20.700
# Name: 1, dtype: float64

# %%
Ob2011.to_json("tmp.json", orient="index")

# %%
Ob2011.to_json?
